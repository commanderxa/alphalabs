# %% [markdown]
# # 2D Motion

# %% [markdown]
# ### **Introduction**
#
# We live in a quite complex world, where motion is considered a synonym of life. In fact, everything we do is related to motion.
#
# Our world is composed of 3 dimensions (3D) in which you can move (jump, run, swim, do backflips, etc.). In this lab, we will handle a big part of that complexity of the world we live in - Motion in two dimensions.
#
# ### **What is it?**
#
# 2D motion is a motion where 2 dimensions are used. Now, compared to 1 dimension, objects in 2 dimensions experience the force from more sides. Such motion is not significantly different from 3D motion, since it allows us to model interaction of objects and the earth much more simply. The main desire to use 2 dimensions is to see how objects will experience gravity.
#
# ### **Example**
#
# The cliché example is a projectile motion - a parabalistic trajectories of thrown objects that under gravitation will eventually fall down. Such a process might be visualized differently. For instance, you may throw a rock or a ball, you may speed up and jump up the hillock on your bike or you might think of the Earth moving around the sun. All of that is an example of projectile motion.
#
# In the past, our ancestors had been using dangerous weapons called catapults to destroy their enemies' fortresses and to conquer cities, however, they did not know any kinematics formulae, they used a method of trial and error to understand the relationship between the angle and the distance cannonball flies. Today, thanks to many curious people as Galileo Galilei and Isaac Newton we know how to calculate complex trajectories that allow us to control the multistage rockets.

# %% [markdown]
# ### **Formulas**
#
# 2D Motion might be calculated using the following formulas:
#
# Fall Velocity: $\vec{v}_y=\vec{v}_{y0}+\vec{a}_yt=\vec{v}_{y0}+\vec{g}t$\
# Move Velocity: $\vec{v}_x=\vec{v_{x0}}+\vec{a}_xt$\
# Position: $x=x_0+\vec{v}_xt+\frac{1}{2}\vec{a}_xt^2$

# %% [markdown]
# # Simulation

# %% [markdown]
# ## Setup
#
# Installing packages (for Google Colab). If this notebook is opened in Google Colab then some packages must be installed to run the code!\
# Then importing the scene and plot settings.

# %%
#@title Run to install MuJoCo and `dm_control` for Google Colab

IS_COLAB = 'google.colab' in str(get_ipython())
if IS_COLAB:
    # download the repository
    # !git clone https://github.com/commanderxa/alphalabs.git
    from alphalabs.mechanics.setup import install_packages_colab
    install_packages_colab()
    import alphalabs.mechanics.plot
    import alphalabs.mechanics.utils as utils
    from alphalabs.mechanics.scene import Scene
else:
    import os, sys
    module_path = os.path.abspath(os.path.join(".."))
    if module_path not in sys.path:
        sys.path.append(module_path)
    # import the scene
    from scene import Scene
    import utils
    import plot

# %% [markdown]
# ## Import
#
# Import all required packages to preform simulations. Packages include simulation engine, plotting libraries and other ones necessary for computations.

# %%
# %env MUJOCO_GL=egl

# simulation
from dm_control import mjcf, mujoco
from dm_control.mujoco import engine

# for video recording
import mediapy

# computations
import numpy as np

# plot charts
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# ## Initial Conditions
#
# In this block constants are defined. They impact the environment, rendering and objects directly.

# %%
# global
IS_IDEAL = True  # specifies if the world is ideal (e.g. no frictions, etc.)
VISCOSITY = 0.00002  # air resistance
DENSITY = 1.2  # air density

# simulation constants
# speed [m/s]
V = 20
# angle in degrees
ANGLE = 30
PLATFORM_LENGTH = 1000  # [m]
MASS = 10  # [kg]

# engine
INTEGRATOR = "RK4"
INTEGRATOR_TIMESTEP = 0.001

# rendering
WIDTH = 1920
HEIGHT = 1080
DPI = 600
DURATION = 10  # (seconds)
FRAMERATE = 30  # (Hz)

LAB_NAME = "2D_motion"
LAB_PATH = f"{LAB_NAME}/{'ideal' if IS_IDEAL else 'real'}"

# %% [markdown]
# Convert degrees to radians

# %%
ANGLE_RAD = ANGLE * np.pi / 180

# %% [markdown]
# ## Model

# %% [markdown]
# ### Objects of Interest
#
# Here we create all the objects that will interact in the world. To model `2D motion` one might create a box that is shot in the sky under a specific angle.

# %%
class Box(object):

    def __init__(self, size: float) -> None:
        self.model = mjcf.RootElement(model="box")

        self.wrapper = self.model.worldbody.add("body", name="wrapper", pos=[0, 0, 0])

        self.box = self.wrapper.add("body", name="box", pos=[0, 0, 0])
        self.box_geom = self.box.add(
            "geom",
            name="box_geom",
            type="box",
            size=[size, size, size],
            mass=MASS,
            rgba=[0.3, 0, 0, 1],
            condim=6,
        )

        self.hidden_box_geom = self.wrapper.add(
            "geom",
            name="hidden_box_geom",
            type="box",
            size=[size, size, size],
            mass=MASS,
            rgba=[0, 0, 0, 0],
            contype=0,
            conaffinity=0,
        )

        self.camera = self.wrapper.add(
            "camera",
            name="front",
            pos=[0, -4, 0],
            euler=[90, 0, 0],
            mode="trackcom",
            fovy=45,
        )

        self.move = self.box.add("joint", name="move", type="slide", axis=[1, 0, 0])
        self.fall = self.box.add("joint", name="fall", type="slide", axis=[0, 0, 1])

        self.box.add("light", directional=False, pos=[0, 0, 10], dir=[0, 0, -1])

# %% [markdown]
# ### World Model
#
# Collecting everything into one general model.

# %%
class Model(object):

    def __init__(self, platform_length: float) -> None:
        self.model = mjcf.RootElement(model="model")

        box_size = 0.5

        # set render info
        self.model.visual.__getattr__("global").offheight = HEIGHT
        self.model.visual.__getattr__("global").offwidth = WIDTH
        self.model.visual.map.znear = 0.001

        # set the simulation constants
        # self.model.option.integrator = "Euler"
        self.model.option.integrator = INTEGRATOR
        self.model.option.timestep = INTEGRATOR_TIMESTEP
        if IS_IDEAL:
            self.model.option.viscosity = 0
            self.model.option.density = 0
        else:
            self.model.option.viscosity = VISCOSITY
            self.model.option.density = DENSITY

        # create the environment (ground)
        self.scene = Scene(length=platform_length, width=10, condim=6)
        self.scene_site = self.model.worldbody.add("site", pos=[0, 0, -box_size * 1.5])
        self.scene_site.attach(self.scene.model)

        # add the box
        self.box = Box(box_size)
        box_site = self.model.worldbody.add("site", pos=[0, 0, 0])
        box_site.attach(self.box.model)

# %% [markdown]
# ## Simulation

# %% [markdown]
# Initializing the `physics` of the simulation and verifying the environment by rendering a picture of the simulation world.

# %%
model = Model(platform_length=PLATFORM_LENGTH).model
physics = mjcf.Physics.from_mjcf_model(model)

# %% [markdown]
# Creating a new movable camera.

# %%
camera = engine.MovableCamera(physics, height=HEIGHT, width=WIDTH)
lookat = (
    abs(physics.named.data.geom_xpos["box/box_geom"].copy())
    - abs(physics.named.data.geom_xpos["box/hidden_box_geom"].copy())
) / 2
camera.set_pose(lookat=lookat, distance=8, azimuth=90, elevation=0)

# %% [markdown]
# First of all, the environment must be verified by rendering a picture.

# %%
mediapy.show_image(physics.render(height=320, width=640, camera_id=0))
mediapy.write_image(utils.prefix_path("preview.png", LAB_PATH), physics.render(height=HEIGHT, width=WIDTH, camera_id=0))

# %% [markdown]
# Get IDs of the objects. They are needed to track the collisions, e.g. to detect when a box is on the ground.

# %%
box_id = physics.model.name2id("box/box_geom", "geom")
ground_id = physics.model.name2id("scene/platform", "geom")
box_track_id = physics.model.name2id("box/wrapper", "body")
box_id, ground_id, box_track_id

# %% [markdown]
# ### Scene Modification
#
# These functions allow to render some objects (trajectories, in this case) that will be visible, but will not interact.

# %%
def add_visual_capsule(scene, point1, point2, radius, rgba):
    """Adds one capsule to an mjvScene."""

    if scene.ngeom >= scene.maxgeom:
        return
    scene.ngeom += 1  # increment ngeom
    # initialise a new capsule, add it to the scene using mjv_connector
    mujoco.mjv_initGeom(
        scene.geoms[scene.ngeom - 1],
        mujoco.mjtGeom.mjGEOM_CAPSULE,
        np.ones(3),
        np.zeros(3),
        np.zeros(9),
        rgba.astype(np.float32),
    )
    mujoco.mjv_connector(
        scene.geoms[scene.ngeom - 1],
        mujoco.mjtGeom.mjGEOM_CAPSULE,
        radius,
        point1,
        point2,
    )


def modify_scene(scn, position):
    """Draw position trace"""
    
    if len(position) > 1:
        for i in range(len(position) - 1):
            rgba = np.array([1, 0, 0, 1])
            radius = 0.2
            point1 = position[i]
            point2 = position[i + 1]
            add_visual_capsule(scn, point1, point2, radius, rgba)

    return position

# %% [markdown]
# ### Simulation Loop

# %%
physics.reset()

# intiialize empty arrays to record data
frames = []
timevals = []
velocity = []
position = []

impact_time_index = None
accelerated = False

min_pos = np.array([np.inf, np.inf, np.inf])
max_pos = np.array([-np.inf, -np.inf, -np.inf])

initial_distance = 15.0
initial_lookat = physics.named.data.geom_xpos["box/box_geom"].copy()
transition_start_time = None
transition_duration = 1.0  # seconds for smooth interpolation

while physics.time() < DURATION:

    current_time = physics.time()

    # Pre-motion idle camera
    if not accelerated and current_time < 1.0:
        if len(frames) < current_time * FRAMERATE:
            camera = engine.MovableCamera(physics, height=HEIGHT, width=WIDTH, max_geom=10000)
            camera.set_pose(lookat=initial_lookat, distance=initial_distance, azimuth=90, elevation=0)
            pixels = camera.render().copy()
            frames.append(pixels)

    # Start movement
    if not accelerated and current_time >= 1.0:
        physics.named.data.qvel["box/move"] = V * np.cos(ANGLE_RAD)
        physics.named.data.qvel["box/fall"] = V * np.sin(ANGLE_RAD)
        accelerated = True
        transition_start_time = current_time

    if impact_time_index is not None and current_time - impact_time_index > 2.0:
        break

    for c in physics.data.contact:
        if (
            impact_time_index is None
            and accelerated
            and box_id in c.geom
            and ground_id in c.geom
            and physics.named.data.qvel["box/fall"] < 0.000001
        ):
            impact_time_index = current_time
            physics.named.data.qvel["box/move"] = 0
            physics.named.data.qvel["box/fall"] = 0

    if accelerated and impact_time_index is None:
        pos = physics.named.data.geom_xpos["box/box_geom"].copy()

        timevals.append(current_time)
        velocity.append(physics.named.data.qvel[:].copy())
        position.append(pos)

        min_pos = np.minimum(min_pos, pos)
        max_pos = np.maximum(max_pos, pos)

    # Dynamic or interpolated camera
    if len(frames) < current_time * FRAMERATE:
        if accelerated:
            center = (min_pos + max_pos) / 2
            extent = max_pos - min_pos
            largest_extent = np.linalg.norm(extent[:2])
            target_distance = largest_extent * 1 + 1.0

            t = (current_time - transition_start_time) / transition_duration
            t = np.clip(t, 0.0, 1.0)

            # Interpolate smoothly
            interp_lookat = (1 - t) * initial_lookat + t * center
            interp_distance = (1 - t) * initial_distance + t * target_distance

            scene_callback = lambda _, _scn: modify_scene(_scn, position)

            camera = engine.MovableCamera(
                physics,
                height=HEIGHT,
                width=WIDTH,
                scene_callback=scene_callback,
                max_geom=10000,
            )
            camera.set_pose(lookat=interp_lookat, distance=interp_distance, azimuth=90, elevation=0)
            pixels = camera.render().copy()
            frames.append(pixels)

    # update the simulation
    physics.step()

# %% [markdown]
# Show and save the video of the simulation

# %%
mediapy.show_video(frames, fps=FRAMERATE)
mediapy.write_video(utils.prefix_path("simulation.mp4", LAB_PATH), images=frames, fps=FRAMERATE)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# Convert data into numpy arrays

# %%
timevals = np.array(timevals) - 1
velocity = np.array(velocity)
position = np.array(position)

# %% [markdown]
# Plot charts with the collected data

# %%
cm = 1 / 2.54
figsize = (8.5 * cm, 3.75 * cm)
fig, ax = plt.subplots(ncols=2, figsize=figsize, dpi=DPI, sharex=False)
fig.subplots_adjust(wspace=1 * cm)

y_labels = ["Velocity, [m/s]", "Height, [m]"]
x_labels = ["Time, [s]", "Range, [m]"]
y_data = [velocity[:, 1], position[:, 2]]
x_data = [timevals, position[:, 0]]

for i in range(2):
    sns.lineplot(x=x_data[i], y=y_data[i], ax=ax[i], linewidth=1, color="red")
    ax[i].set_ylabel(y_labels[i], fontsize=7, labelpad=2)
    ax[i].set_xlabel(x_labels[i], fontsize=7, labelpad=2)
    ax[i].tick_params(labelsize=6)
    ax[i].tick_params(which="both", direction="in", top=True, right=True, length=2)
    ax[i].xaxis.set_major_locator(ticker.MaxNLocator(nbins=5))
    ax[i].yaxis.set_major_locator(ticker.MaxNLocator(nbins=5))

max_height_idx = np.where(position == max(position[:, 2]))[0][0]
max_height = position[max_height_idx]

ax[1].set_ylim(top=np.ceil(max_height)[2])
ax[0].axvline(
    x=[timevals[max_height_idx]],
    linewidth=0.5,
    label=f"Peak Time: {(timevals[max_height_idx]):.2f} s",
    color="green",
)
ax[1].axvline(
    x=[max_height[0]],
    linewidth=0.5,
    label=f"Max Height: {max_height[2]:.2f} m",
    color="green",
)

ax[0].legend(fontsize=5, handlelength=1).get_frame().set_linewidth(0.5)
ax[1].legend(fontsize=5, handlelength=1).get_frame().set_linewidth(0.5)

fig.savefig(utils.prefix_path("chart.png", LAB_PATH), bbox_inches="tight")

# %% [markdown]
# ## Error Analysis
#
# Calculation of **Root Mean Square Error** (RMSE) for position and velocities.

# %% [markdown]
# ### The Predicted Values
#
# Compute the predicted values according to the formulae:
#
# 1. Fall Velocity: $\vec{v}_y=\vec{v}_{y0}+\vec{a}_yt=\vec{v}_{y0}+\vec{g}t$
# 2. Move Velocity: $\vec{v}_x=\vec{v_{x0}}+\vec{a}_xt$
# 3. Position: $x=\frac{v^2\cdot\sin{2\theta}}{|g|}$
#
# Using `velocity` and `position` rather than a last value from them gives out the predictions for each timestep.\
# The last value can be retrieved by indixing with `[-1]`.

# %%
# compute predictions
v_x0 = V * np.cos(ANGLE_RAD)
v_y0 = V * np.sin(ANGLE_RAD)
velocity_y_pred = v_y0 + physics.model.opt.gravity[-1] * timevals
velocity_x_pred = v_x0 + 0 * timevals
# position_pred = 0 + v_x0 * timevals + 0
position_pred = (np.square(V) * np.sin(2 * ANGLE_RAD)) / abs(physics.model.opt.gravity[-1])
# get last values
v_y_pred = velocity_y_pred[-1]
v_x_pred = velocity_x_pred[-1]
x_pred = position_pred
print(f"According to formulae:\n1. Velocity is (x, y): ({v_x_pred:.3f}, {v_y_pred:.3f});\n2. Position is: {x_pred:.3f};")

# %% [markdown]
# ### The Actual Values
#
# Get the actual values from the simulation.

# %%
# get last actual values
v_x_actual = velocity[-1][0]
v_y_actual = velocity[-1][1]
x_actual = position[-1][0]
print(f"The actual values from the simulation:\n1. Velocity is (x, y): ({v_x_actual:.3f}, {v_y_actual:.3f});\n2. Position is: {x_actual:.3f};")

# %% [markdown]
# ### RMS Error
#
# Compute the error for last values.

# %%
v_x_err = utils.root_mean_squared_error(velocity[:, 0], velocity_x_pred)
v_y_err = utils.root_mean_squared_error(velocity[:, 1], velocity_y_pred)
x_err = utils.root_mean_squared_error(position[:, 0], position_pred)

# %%
cm = 1 / 2.54
figsize = (8.5 * cm, 3.75 * cm)
fig, ax = plt.subplots(ncols=2, figsize=figsize, dpi=DPI)
fig.subplots_adjust(wspace=1 * cm)

y_labels = [r"$v_x$ error", r"$v_y$ error"]
x_labels = ["Time, [s]", "Time, [s]"]
data = [v_x_err, v_y_err]

for i in range(2):
    sns.lineplot(x=timevals, y=data[i], ax=ax[i], linewidth=1, color="red")
    ax[i].set_ylabel(y_labels[i], fontsize=7, labelpad=2)
    ax[i].set_xlabel(x_labels[i], fontsize=7, labelpad=2)
    ax[i].tick_params(which="both", direction="in", labelsize=6, top=True, right=True, length=2)
    ax[i].yaxis.get_offset_text().set_fontsize(5)
    ax[i].set_ymargin(0.1)
    ax[i].set_xmargin(0.1)

fig.savefig(utils.prefix_path("error_RMS.png", LAB_PATH), bbox_inches="tight")

# %% [markdown]
# ### Absolute Percentage Error
#
# Compute the error for last values in percent, `%`.

# %%
v_x_err_p = utils.absolute_percentage_error(velocity[:, 0], velocity_x_pred)
v_y_err_p = utils.absolute_percentage_error(velocity[:, 1], velocity_y_pred)
x_err_p = utils.absolute_percentage_error(position[:, 0], position_pred)

# %%
cm = 1 / 2.54
figsize = (8.5 * cm, 3.75 * cm)
fig, ax = plt.subplots(ncols=2, figsize=figsize, dpi=DPI)
fig.subplots_adjust(wspace=1 * cm)

y_labels = [r"$v_x$ error", r"$v_y$ error"]
x_labels = ["Time, [s]", "Time, [s]"]
data = [v_x_err_p, v_y_err_p]

for i in range(2):
    sns.lineplot(x=timevals, y=data[i], ax=ax[i], linewidth=1, color="red")
    ax[i].set_ylabel(y_labels[i], fontsize=7, labelpad=2)
    ax[i].set_xlabel(x_labels[i], fontsize=7, labelpad=2)
    ax[i].tick_params(which="both", direction="in", labelsize=6, top=True, right=True, length=2)
    ax[i].yaxis.get_offset_text().set_fontsize(5)
    ax[i].set_ymargin(0.1)
    ax[i].set_xmargin(0.1)

fig.savefig(utils.prefix_path("error_abs_percent.png", LAB_PATH), bbox_inches="tight")
